# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# read data
air = pd.read_csv("air_quality.csv" , sep = ',' )
air
# Out:
# C:\Users\Salima\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# ...

# %%
air['date'] = pd.to_datetime(air['date'])
# get data from 2013 to 2015
air= air [ (air ['date'] > '2002 - 12 - 31' ) &  (air ['date'] < '2016 - 1 - 1') ]
air
# Out:
#        stn_code sampling_date           state   location  \
# 1036       95.0      1/2/2004  Andhra Pradesh  Hyderabad
# 1037       95.0      1/5/2004  Andhra Pradesh  Hyderabad
# 1038       95.0      1/9/2004  Andhra Pradesh  Hyderabad
# 1039       95.0     1/12/2004  Andhra Pradesh  Hyderabad
# 1040       95.0      16-01-04  Andhra Pradesh  Hyderabad
# ...         ...           ...             ...        ...
# 435734     SAMP      15-12-15     West Bengal   ULUBERIA
# 435735     SAMP      18-12-15     West Bengal   ULUBERIA
# 435736     SAMP      21-12-15     West Bengal   ULUBERIA
# 435737     SAMP      24-12-15     West Bengal   ULUBERIA
# 435738     SAMP      29-12-15     West Bengal   ULUBERIA
#
#                                               agency             type   so2  \
# 1036    Andhra Pradesh State Pollution Control Board  Industrial Area  12.9
# 1037    Andhra Pradesh State Pollution Control Board  Industrial Area  10.4
# ...

# %%
# retrieve only the columns that matters in our study
air = air[['date', 'so2', 'no2' , 'rspm' ,'spm']].copy()

# %%
air['Year'] = air['date'].dt.year

air = air.groupby('Year')['so2' ,'no2' ,'rspm' , 'spm'].mean()
# Out:
# <ipython-input-31-981b3c98d76e>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   air = air.groupby('Year')['so2' ,'no2' ,'rspm' , 'spm'].mean()

# %%
temperature= pd.read_csv("temperatures.csv" , sep = ',' )
temperature
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
temperature = temperature [(temperature['YEAR'] > 2002)  ]

# %%
air['Year'] = air.index
fig, axes= plt.subplots(2 , 2 , figsize=(20, 12)  )
  
air_so2 = air[['so2' , 'Year']].dropna()
air_no2 = air[['no2' , 'Year']].dropna()
air_rspm = air[['rspm' , 'Year']].dropna()


sns.barplot(y="so2", x="Year", palette='coolwarm', data=air_so2, ax=axes[0,0] )
axes[0,0].set_title("Average annual so2 in India from 2003 to 2015")

sns.barplot(y="no2", x="Year",palette='rocket', data=air_no2, ax=axes[0,1] )
axes[0,1].set_title("Average annual no2 in India from 2003 to 2015")

sns.barplot(y="rspm", x="Year", palette='mako',data=air_rspm, ax=axes[1,0] )
axes[1,0].set_title("Average annual rspm in India from 2003 to 2015 ")

sns.barplot(y="ANNUAL", x="YEAR", palette = 'mako', data=temperature, ax=axes[1,1])
axes[1,1].set_title("Average annual temperatures in India from 2003 to 2015 ")
plt.savefig ('chart.png')


plt.tight_layout()

# %%
temperature[['ANNUAL']]
# Out:
#      ANNUAL
# 102   29.75
# 103   29.79
# 104   29.60
# 105   30.06
# 106   29.84
# 107   29.64
# 108   30.30
# 109   30.13
# 110   29.82
# 111   29.81
# 112   29.81
# 113   29.72
# 114   29.90
# 115   31.63
# 116   31.42
